# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
import matplotlib.pyplot as plt
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
# your sample input of graph
graph1 = {
    "A": {"B": 30, "D": 45},
    "B": {"A": 30, "C": 68, "D": 49, "E": 27},
    "C": {"B": 68, "E": 75},
    "D": {"A": 45, "B": 49, "E": 15, "F": 36},
    "E": {"B": 27, "C": 75, "D": 15, "F": 18, "G": 19},
    "F": {"D": 36, "E": 18, "G": 21},
    "G": {"E": 19, "F": 21},
}

# %%
#run prims algorithm for sample input
def prim_algorithm(graph1):
  min_tree={}
  visited=set()
  min_tree[list(graph1.keys())[0]] = []
  min_weight = 0

  while len(visited) < len(graph1):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph1[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

  return min_tree, min_weight
mst, min_weight = prim_algorithm(graph1)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'E': [], 'D': [], 'F': [], 'G': [], 'C': []}
# Minimum Weight:  207

# %% [markdown]
# ### Kruskal's Algorithm
#
# Kruskal's algorithm is a greedy algorithm that finds a Minimum Spanning Tree (MST) for a connected, weighted undirected graph. It finds a subset of the edges that forms a tree that includes every vertex, where the total weight of all the edges in the tree is minimized.
#
# The algorithm works as follows:
#
# 1.  **Create a list of all edges** in the graph and sort them in non-decreasing order of their weights.
# 2.  **Initialize a Disjoint Set Union (DSU) data structure** where each vertex is in its own separate set.
# 3.  **Iterate through the sorted edges**: For each edge `(u, v)` with weight `w`:
#     *   Check if the vertices `u` and `v` are already in the same set using the `find` operation.
#     *   If they are not in the same set, add the edge `(u, v)` to the MST and unite the sets of `u` and `v` using the `union` operation.
# 4.  Continue until `V-1` edges have been added to the MST, where `V` is the number of vertices in the graph.

# %%
def find(parent, i):
    if parent[i] == i:
        return i
    parent[i] = find(parent, parent[i])
    return parent[i]

def union(parent, rank, i, j):
    root_i = find(parent, i)
    root_j = find(parent, j)
    if root_i != root_j:
        if rank[root_i] < rank[root_j]:
            parent[root_i] = root_j
        elif rank[root_i] > rank[root_j]:
            parent[root_j] = root_i
        else:
            parent[root_j] = root_i
            rank[root_i] += 1
        return True
    return False

def kruskal_algorithm(graph1):
    edges = []
    for u in graph:
        for v, weight in graph[u].items():

            if (weight, v, u) not in edges:
                edges.append((weight, u, v))

    edges.sort()

    num_vertices = len(graph1)
    parent = {vertex: vertex for vertex in graph1}
    rank = {vertex: 0 for vertex in graph1}

    mst_edges = []
    min_weight = 0
    num_mst_edges = 0

    for weight, u, v in edges:
        if num_mst_edges == num_vertices - 1:
            break

        if union(parent, rank, u, v):
            mst_edges.append((u, v, weight))
            min_weight += weight
            num_mst_edges += 1

    return mst_edges, min_weight

mst_kruskal, min_weight_kruskal = kruskal_algorithm(graph1)

print("Minimum Spanning Tree (Kruskal's): ", mst_kruskal)
print("Minimum Weight (Kruskal's): ", min_weight_kruskal)
# Out:
# Minimum Spanning Tree (Kruskal's):  [('A', 'D', 5), ('C', 'E', 5), ('D', 'F', 6), ('A', 'B', 7), ('B', 'E', 7), ('E', 'G', 9)]
# Minimum Weight (Kruskal's):  39
